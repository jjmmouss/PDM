# %%
import networkx as nx # version 2.2
import matplotlib.pyplot as plt
import re
import cvxpy as cp
import operator #to sort elements in a list of tuples
import itertools
import math
import numpy as np
import os
import sys
import time
import random

import Init_NetRate as Init
import cvxpy as cp
import Cascade_generation_functions_NetRate as Gen
import CVX_functions as cvx

# %%
'''
Create the matrix Mi for the ADMM method

Each cell k,l in Mi is one if in cascade k node l infected node i, 0 otherwise

Input :
    cascade_dic : a dictionnary of all cascade (in a graph object, DAG)
    node : an int describing which node we are considering in the ADMM iteration
    number_of_nodes : number of nodes in the underlying network (we assume that rhe union of all cascades cover all the nodes)
'''
def Create_matrix_Mi_and_Ti(cascade_dic,node,number_of_nodes,window) : 
    M_i = np.zeros((len(cascade_dic),number_of_nodes))
    T_i = np.zeros((len(cascade_dic),number_of_nodes))
    index_to_delete =[]
    for cascade in cascade_dic :
        c = cascade_dic[cascade] # graph object
        if node in c.nodes():
            t_i = c.node[node]["time"]
            parent_list = list(c.predecessors(node)) # create a list of all nodes (int) that where infected before node i in the cascade
            for parent in parent_list :
                t_parent = c.node[parent]["time"]
                M_i[cascade,parent] = 1
                T_i[cascade,parent] = (t_i-t_parent)
                if (t_i-t_parent)<=0:
                    print("Time error, the flow of time is reversed the world's end is near")
        else :
            for j in c.nodes() :
                t_j = c.node[j]["time"]
                T_i[cascade,j] = (window-t_j) # SIGNE is now correct !
                
        if np.all(M_i[cascade,:]==0):
            index_to_delete.append(cascade)
    M_i = np.delete(M_i,(index_to_delete),axis=0)
                
    return M_i,T_i

# %%
def Compute_objective_value_for_one_node(alpha_mat_i,cascade_dic,window,eps,node_i) :
    obj_i = 0
    for cascs in cascade_dic :
        c = cascade_dic[cascs]
        if node_i in c.nodes():
            t_i = c.nodes[node_i]["time"]
            parents_i_list = list(c.predecessors(node_i))
            sum_tmp = 0
            for parent in parents_i_list :
                t_parent = c.nodes[parent]["time"]
                obj_i += alpha_mat_i[parent]*(t_i-t_parent)
                sum_tmp += alpha_mat_i[parent]
            if sum_tmp<=0 :
                if len(parents_i_list)>0 :
                    #print("Attention log ill defined incoming")
                    obj_i -=math.log(eps)
            else :
                obj_i -= math.log(sum_tmp)
        else :
            for j in c.nodes():
                t_j = c.nodes[j]["time"]
                obj_i += alpha_mat_i[j]*(window-t_j)
    return obj_i

def Compute_true_objective_value_per_node(G_true,cascade_dic,window,node_i):
    obj_i = 0
    for cascs in cascade_dic :
        c = cascade_dic[cascs]
        if node_i in c.nodes():
            t_i = c.nodes[node_i]["time"]
            parent_i_list = list(c.predecessors(node_i))
            sum_tmp = 0
            for parent in parent_i_list :
                if (parent,node_i) in G_true.edges():
                    t_parent = c.nodes[parent]["time"]
                    try :
                        alpha_ji = G_true.edges[(parent,node_i)]["weight"][0]
                    except TypeError :
                        alpha_ji = G_true.edges[(parent,node_i)]["weight"]
                    obj_i += alpha_ji*(t_i-t_parent)
                    sum_tmp += alpha_ji
            if sum_tmp == 0:
                if len(parent_i_list)>0 :
                    print("Oulala")
            else :
                obj_i -= math.log(sum_tmp)
        else :
            for j in c.nodes() :
                if (j,i) in G_true.edges():
                    t_j = c.nodes[j]["time"]
                    try :
                        alpha_ji = G_true.edges[(j,i)]["weight"][0]
                    except TypeError :
                        alpha_ji = G_true.edges[(j,i)]["weight"]
                    obj_i += alpha_ji*(window-t_j)
    return obj_i

# %%
network_file_name = "./Graph_test_SG.txt"
cascade_file_name = "./Cascade_test_SG.txt"
window = 10
model=0 # not important but needed. When constructing the underlying network specify that we use the exponential law
beta = 1 # used for the construction of the cascades, probability of the edge to transmit the infection
eps = 0.0005
alpha_max = 10 #bound alpha from above
alpha_init = 0.01 #initial value of the infectious rates
iter_ADMM = 50 #number of itteration for 1 node in the ADMM method. This is a parameter to tune
iter_GD = 1000 #number of iterations of the gradient descent
gamma = 0.000005 # Learning rate of the GD for alpha (maybe too small)
#gamma = 0.000005

# %%
G_true = Init.Load_ground_truth(network_file_name)
G_star, DAG_C_dic = Init.Init(cascade_file_name)
N = G_true.number_of_nodes()

# G_true = Gen.Generate_random_graph(30,60)
# Cascades = Gen.Generate_all_cascades(G_true,-1000,window,model,beta)
# Gen.Save_cascade_to_file("Cascade_test_ADMM.txt",Cascades,G_true)
# Gen.Save_graph_to_file("Graph_test_ADMM.txt",G_true)
# G_star,DAG_C_dic = Init.Init("Cascade_test_ADMM.txt")
# N = G_true.number_of_nodes()
# Out:
# All nodes were read

# %%
A_hat = np.zeros((N,N))
u = 2 # used for the gradient descent of rho and as a penalizer and the constrain

# %%
t_start_global = time.time()
dic_of_obj_per_node_per_iter = {}
obj_per_node = []
for i in G_true.nodes :
    print("Node : ",i)
    t_start_node_i = time.time()
    dic_of_obj_per_node_per_iter[i] = []
    
    
    '''
    initialization
    '''
    a_k = np.ones((N,1))*alpha_init
    a_k[i]=0
    M_i,T_i = Create_matrix_Mi_and_Ti(DAG_C_dic,i,N,window) # TO do : consider to use sparse matrix  
    grad_i = (np.sum(T_i,axis=0).T)
    for bla in range(0,len(grad_i)):
        if grad_i[bla]==0 :
            a_k[bla]=0
   
    z = a_k.copy()         
    rho = np.zeros((M_i.shape[0],1))
    S_i = np.matmul(M_i,z)
    
    
    #Start iteration of ADMM
    for k in range(0,iter_ADMM) :
        '''
        Update alpha using gradient descent
        '''
        grad = grad_i + np.matmul(rho.T,M_i)
        for j in range(0,iter_GD):
            grad_j = grad - u*(np.matmul(M_i.T,(S_i-np.matmul(M_i,a_k))).T) # sign is correct
            a_k = a_k - gamma*grad_j.T
            a_k = np.maximum(a_k,0)
            a_k = np.minimum(a_k,alpha_max)
            
        '''
        update S_i and rho for each cascades via the closed form formula and the gradient descent respectively
        '''
        for cascs in range(0,M_i.shape[0]) :
            c = DAG_C_dic[cascs]
            Malpha = np.matmul(M_i[cascs,:],a_k)
#             Malpha = 0
#             if i in c.nodes :
#                 parent_i_c = list(c.predecessors(i))
#                 for papa in parent_i_c :
#                     Malpha += a_k[papa]
#             sqrt_delta = math.sqrt((rho[cascs]+Malpha)**2 + 4*u)
#             S_i[cascs] = ((rho[cascs]+Malpha)+sqrt_delta)/(2*u)
#             if i in c.nodes() and len(list(c.predecessors(i)))>0 :
            sqrt_delta = math.sqrt((rho[cascs]+u*Malpha)**2+4*u)
            S_i[cascs] = (rho[cascs]+u*Malpha + sqrt_delta)/(2*u)
            if S_i[cascs]<0 :
                print("Huston Huston we have a probleme")
            if S_i[cascs] ==0 :
                print("one component of S_i is zero")
#                 rho[cascs] = rho[cascs]-u*(S_i[cascs]-Malpha)
#             else :
#                 S_i[cascs] = (rho[cascs]+u*Malpha)/u

            rho[cascs] = rho[cascs]-u*(S_i[cascs]-Malpha)
            
        '''compute the objective function for node i in iteration k'''
        if k%5 ==0 :
            print(k)
            obj_i_k = Compute_objective_value_for_one_node(a_k,DAG_C_dic,window,eps,i)
            dic_of_obj_per_node_per_iter[i].append(obj_i_k)
    A_hat[:,i] = a_k.flatten()
    t_end_node_i = time.time()
    print("computation time for node i : ", t_end_node_i-t_start_node_i)
t_end_global = time.time()
print("total computation time : ",t_end_global-t_start_global)
# Out:
# Node :  0
# 0
# 5
# 10
# 15
# 20
# 25
# 30
# 35
# 40
# 45
# computation time for node i :  2.7498204708099365
# Node :  1
# 0
# 5
# 10
# 15
# 20
# 25
# 30
# 35
# 40
# 45
# computation time for node i :  1.9257628917694092
# Node :  2
# 0
# 5
# 10
# 15
# 20
# 25
# 30
# 35
# 40
# 45
# computation time for node i :  3.3430256843566895
# Node :  3
# 0
# 5
# 10
# 15
# 20
# 25
# 30
# 35
# 40
# 45
# computation time for node i :  1.9829864501953125
# Node :  4
# 0
# 5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-129-b94131d954ef> in <module>
#      64         if k%5 ==0 :
#      65             print(k)
# ---> 66             obj_i_k = Compute_objective_value_for_one_node(a_k,DAG_C_dic,window,eps,i)
#      67             dic_of_obj_per_node_per_iter[i].append(obj_i_k)
#      68     A_hat[:,i] = a_k.flatten()
#
# <ipython-input-29-b5b5055c625d> in Compute_objective_value_for_one_node(alpha_mat_i, cascade_dic, window, eps, node_i)
#      10                 t_parent = c.nodes[parent]["time"]
#      11                 obj_i += alpha_mat_i[parent]*(t_i-t_parent)
# ---> 12                 sum_tmp += alpha_mat_i[parent]
#      13             if sum_tmp<=0 :
#      14                 if len(parents_i_list)>0 :
#
# KeyboardInterrupt:

# %%
'''
Precision and recall computation
'''
correct = 0
edge_G_star = list(G_star.edges())
G_star.remove_edges_from(edge_G_star)
for i in range(0,G_true.number_of_nodes()):
    for j in range(0,G_true.number_of_nodes()):
        if A_hat[i,j] >0:
            G_star.add_edge(i,j)
            if (i,j) in G_true.edges():
                correct +=1
#                 print("edge ",(i,j))
#                 print("alpha is ",A_hat[i,j])
print("Precision :",correct/G_star.number_of_edges())
print("Recall :",correct/G_true.number_of_edges())
print("Number of correct infered edges : ",correct)
print("Number of edges in G_hat :",G_star.number_of_edges())
print("Number of edges in the true network ",G_true.number_of_edges())
# Out:
# Precision : 0.9298245614035088
# Recall : 0.8833333333333333
# Number of correct infered edges :  53
# Number of edges in G_hat : 57
# Number of edges in the true network  60

# %%
'''
mean square error
'''
mse = 0
nb_correcte_edges=0
for edge in G_true.edges():
    if edge in G_star.edges():
        nb_correcte_edges +=1
        try:
            true_alpha = G_true.edges[edge]["weight"][0]
        except TypeError:
            true_alpha = G_true.edges[edge]["weight"]
        approx_alpha = A_hat[edge[0],edge[1]]
        mse += pow((true_alpha-approx_alpha),2) # mean square error
#         print("For edge " + str(edge)+ " the true weight is : " + str(true_alpha))
#         print("For edge " + str(edge)+ " the approx weight is : " + str(approx_alpha))
try :
    mse = mse/nb_correcte_edges
except ZeroDivisionError:
    print ("There is no correct edge")
print(" Mean square error is : ",mse)
# Out:
#  Mean square error is :  0.002212470682468784

# %%
true_total_obj = 0
true_obj_per_node = []
for i in G_true.nodes():
    obj_i = Compute_true_objective_value_per_node(G_true,DAG_C_dic,window,i)
    print("Node %i has objective value %f" %(i,obj_i))
    true_obj_per_node.append(obj_i)
    true_total_obj += obj_i
print("true objective value : ",true_total_obj)


total_obj = 0
obj_per_node = []
for i in G_true.nodes():
    alpha_mat_i = A_hat[:,i]
    obj_i = Compute_objective_value_for_one_node(alpha_mat_i,DAG_C_dic,window,eps,i)
    print("Node %i has objective value %f" %(i,obj_i))
    obj_per_node.append(obj_i)
    total_obj += obj_i
print("Infered objective value : ", total_obj)
# Out:
# Node 0 has objective value 130.840255
# Node 1 has objective value 0.000000
# Node 2 has objective value 662.817534
# Node 3 has objective value 32.394744
# Node 4 has objective value 693.260137
# Node 5 has objective value 637.848855
# Node 6 has objective value 25.030081
# Node 7 has objective value 398.632000
# Node 8 has objective value 843.062271
# Node 9 has objective value 635.864726
# Node 10 has objective value 498.218956
# Node 11 has objective value 665.089551
# Node 12 has objective value 267.145793
# Node 13 has objective value 810.951177
# Node 14 has objective value 115.492529
# Node 15 has objective value 55.700474
# Node 16 has objective value 432.475465
# Node 17 has objective value 509.268177
# Node 18 has objective value 23.503738
# Node 19 has objective value 256.035816
# Node 20 has objective value 0.000000
# Node 21 has objective value 0.000000
# Node 22 has objective value 0.000000
# Node 23 has objective value 668.738137
# Node 24 has objective value 775.408540
# Node 25 has objective value 769.128807
# Node 26 has objective value 478.887955
# Node 27 has objective value 753.643116
# Node 28 has objective value 967.517425
# Node 29 has objective value 471.166987
# Node 30 has objective value 1.862687
# Node 31 has objective value 390.093056
# Node 32 has objective value 422.903368
# Node 33 has objective value 630.384175
# Node 34 has objective value 735.373196
# Node 35 has objective value 931.465600
# Node 36 has objective value 673.209745
# Node 37 has objective value 0.000000
# Node 38 has objective value 830.882236
# Node 39 has objective value 93.411567
# Node 40 has objective value 525.308125
# Node 41 has objective value 658.988382
# Node 42 has objective value 744.267297
# Node 43 has objective value 532.505264
# Node 44 has objective value 703.922659
# Node 45 has objective value 5.801229
# Node 46 has objective value 368.050988
# Node 47 has objective value 557.866359
# Node 48 has objective value 330.310686
# Node 49 has objective value 0.000000
# Node 50 has objective value 0.000000
# Node 51 has objective value 812.955162
# Node 52 has objective value 451.868252
# Node 53 has objective value 675.740094
# Node 54 has objective value 369.233020
# Node 55 has objective value 442.213485
# Node 56 has objective value 225.233584
# Node 57 has objective value 416.546449
# Node 58 has objective value 608.138445
# Node 59 has objective value 713.865549
# Node 60 has objective value 0.000000
# Node 61 has objective value 596.828275
# Node 62 has objective value 584.256853
# Node 63 has objective value 410.019106
# Node 64 has objective value 615.467167
# Node 65 has objective value 461.360564
# Node 66 has objective value 604.343114
# Node 67 has objective value 382.722441
# Node 68 has objective value 659.591032
# Node 69 has objective value 543.785336
# Node 70 has objective value 403.478623
# Node 71 has objective value 1025.018493
# Node 72 has objective value 486.081881
# Node 73 has objective value 656.245757
# Node 74 has objective value 344.361769
# Node 75 has objective value 297.800624
# Node 76 has objective value 927.805789
# Node 77 has objective value 174.049290
# Node 78 has objective value 622.729885
# Node 79 has objective value 440.964363
# Node 80 has objective value 328.769624
# Node 81 has objective value 0.000000
# Node 82 has objective value 902.155348
# Node 83 has objective value 560.466553
# Node 84 has objective value 683.833641
# Node 85 has objective value 316.112259
# Node 86 has objective value 292.331310
# Node 87 has objective value 61.624293
# Node 88 has objective value 0.000000
# Node 89 has objective value 477.835658
# Node 90 has objective value 231.236143
# Node 91 has objective value 618.856347
# Node 92 has objective value 0.000000
# Node 93 has objective value 468.369615
# Node 94 has objective value 637.840998
# Node 95 has objective value 688.942205
# Node 96 has objective value 264.190303
# Node 97 has objective value 294.933786
# Node 98 has objective value 214.929158
# Node 99 has objective value 850.219162
# Node 100 has objective value 466.560148
# Node 101 has objective value 863.897375
# Node 102 has objective value 626.721142
# Node 103 has objective value 647.689443
# Node 104 has objective value 632.718519
# Node 105 has objective value 555.256236
# Node 106 has objective value 0.000000
# Node 107 has objective value 604.393083
# Node 108 has objective value 381.831666
# Node 109 has objective value 840.560128
# Node 110 has objective value 0.000000
# Node 111 has objective value 607.410306
# Node 112 has objective value 0.000000
# Node 113 has objective value 575.020049
# Node 114 has objective value 155.282457
# Node 115 has objective value 189.551445
# Node 116 has objective value 823.572686
# Node 117 has objective value 517.323698
# Node 118 has objective value 474.381346
# Node 119 has objective value 850.008247
# Node 120 has objective value 14.478390
# Node 121 has objective value 0.000000
# Node 122 has objective value 59.753892
# Node 123 has objective value 0.000000
# Node 124 has objective value 171.593664
# Node 125 has objective value 0.000000
# Node 126 has objective value 417.618517
# Node 127 has objective value 781.132615
# Node 128 has objective value 680.949172
# Node 129 has objective value 256.476392
# Node 130 has objective value 6.276193
# Node 131 has objective value 0.000000
# Node 132 has objective value 607.011335
# Node 133 has objective value 711.097283
# Node 134 has objective value 693.403534
# Node 135 has objective value 746.763731
# Node 136 has objective value 368.854084
# Node 137 has objective value 0.000000
# Node 138 has objective value 0.000000
# Node 139 has objective value 107.672335
# Node 140 has objective value 157.328923
# Node 141 has objective value 7.104583
# Node 142 has objective value 834.744872
# Node 143 has objective value 703.076348
# Node 144 has objective value 319.226668
# Node 145 has objective value 665.652400
# Node 146 has objective value 681.191216
# Node 147 has objective value 901.789081
# Node 148 has objective value 0.000000
# Node 149 has objective value 41.675410
# Node 150 has objective value 0.000000
# Node 151 has objective value 0.000000
# Node 152 has objective value 661.589107
# Node 153 has objective value 624.184548
# Node 154 has objective value 435.403855
# Node 155 has objective value 314.839518
# Node 156 has objective value 647.948930
# Node 157 has objective value 0.000000
# Node 158 has objective value 764.764656
# Node 159 has objective value 875.301059
# Node 160 has objective value 455.762950
# Node 161 has objective value 270.998211
# Node 162 has objective value 723.165014
# Node 163 has objective value 0.000000
# Node 164 has objective value 839.400080
# Node 165 has objective value 0.000000
# Node 166 has objective value 634.702995
# Node 167 has objective value 395.408521
# Node 168 has objective value 599.926867
# Node 169 has objective value 585.686518
# Node 170 has objective value 496.147283
# Node 171 has objective value 526.987766
# Node 172 has objective value 761.962359
# Node 173 has objective value 596.510531
# Node 174 has objective value 330.064210
# Node 175 has objective value 0.000000
# Node 176 has objective value 742.117321
# Node 177 has objective value 0.000000
# Node 178 has objective value 15.307069
# Node 179 has objective value 653.294275
# Node 180 has objective value 0.000000
# Node 181 has objective value 189.177142
# Node 182 has objective value 2.885098
# Node 183 has objective value 787.081450
# Node 184 has objective value 183.553562
# Node 185 has objective value 621.306005
# Node 186 has objective value 663.530244
# Node 187 has objective value 301.787878
# Node 188 has objective value 257.108276
# Node 189 has objective value 828.638157
# Node 190 has objective value 0.000000
# Node 191 has objective value 279.832802
# Node 192 has objective value 335.629883
# Node 193 has objective value 122.017829
# Node 194 has objective value 222.796342
# Node 195 has objective value 0.000000
# Node 196 has objective value 176.117340
# Node 197 has objective value 0.000000
# Node 198 has objective value 589.659540
# Node 199 has objective value 131.320518
# true objective value :  82951.0449879688
# Node 0 has objective value 223.171404
# Node 1 has objective value 0.000000
# Node 2 has objective value 661.026436
# Node 3 has objective value 30.713356
# Node 4 has objective value 688.988763
# Node 5 has objective value 634.351657
# Node 6 has objective value 24.640475
# Node 7 has objective value 398.200497
# Node 8 has objective value 839.575602
# Node 9 has objective value 634.269475
# Node 10 has objective value 498.196929
# Node 11 has objective value 662.311698
# Node 12 has objective value 298.735578
# Node 13 has objective value 808.181273
# Node 14 has objective value 115.221183
# Node 15 has objective value 55.908524
# Node 16 has objective value 431.753075
# Node 17 has objective value 507.611211
# Node 18 has objective value 23.466533
# Node 19 has objective value 255.893861
# Node 20 has objective value 0.000000
# Node 21 has objective value 0.000000
# Node 22 has objective value 0.000000
# Node 23 has objective value 668.231204
# Node 24 has objective value 773.913024
# Node 25 has objective value 768.467444
# Node 26 has objective value 478.509388
# Node 27 has objective value 826.533632
# Node 28 has objective value 966.561857
# Node 29 has objective value 469.838304
# Node 30 has objective value 1.005357
# Node 31 has objective value 388.789005
# Node 32 has objective value 421.838213
# Node 33 has objective value 626.108100
# Node 34 has objective value 733.589226
# Node 35 has objective value 1022.013621
# Node 36 has objective value 672.591420
# Node 37 has objective value 0.000000
# Node 38 has objective value 830.484399
# Node 39 has objective value 93.308263
# Node 40 has objective value 521.954918
# Node 41 has objective value 658.854068
# Node 42 has objective value 743.828725
# Node 43 has objective value 530.713511
# Node 44 has objective value 703.823066
# Node 45 has objective value 5.537754
# Node 46 has objective value 368.049635
# Node 47 has objective value 556.999729
# Node 48 has objective value 367.138837
# Node 49 has objective value 0.000000
# Node 50 has objective value 0.000000
# Node 51 has objective value 810.394997
# Node 52 has objective value 450.534050
# Node 53 has objective value 672.692116
# Node 54 has objective value 368.931406
# Node 55 has objective value 441.918671
# Node 56 has objective value 224.451990
# Node 57 has objective value 415.320334
# Node 58 has objective value 604.505402
# Node 59 has objective value 710.292979
# Node 60 has objective value 0.000000
# Node 61 has objective value 596.535664
# Node 62 has objective value 583.852689
# Node 63 has objective value 409.500705
# Node 64 has objective value 612.294667
# Node 65 has objective value 460.741611
# Node 66 has objective value 597.509112
# Node 67 has objective value 381.810872
# Node 68 has objective value 659.372025
# Node 69 has objective value 541.222693
# Node 70 has objective value 403.476833
# Node 71 has objective value 1022.509893
# Node 72 has objective value 483.140945
# Node 73 has objective value 653.683246
# Node 74 has objective value 343.241785
# Node 75 has objective value 297.584471
# Node 76 has objective value 926.107366
# Node 77 has objective value 173.589064
# Node 78 has objective value 621.149193
# Node 79 has objective value 440.763553
# Node 80 has objective value 327.096286
# Node 81 has objective value 0.000000
# Node 82 has objective value 901.277553
# Node 83 has objective value 559.645488
# Node 84 has objective value 683.103000
# Node 85 has objective value 424.139831
# Node 86 has objective value 292.092345
# Node 87 has objective value 61.534106
# Node 88 has objective value 0.000000
# Node 89 has objective value 485.181502
# Node 90 has objective value 230.985207
# Node 91 has objective value 616.113549
# Node 92 has objective value 0.000000
# Node 93 has objective value 468.369458
# Node 94 has objective value 632.980094
# Node 95 has objective value 683.171571
# Node 96 has objective value 264.034759
# Node 97 has objective value 295.011251
# Node 98 has objective value 407.327243
# Node 99 has objective value 865.752889
# Node 100 has objective value 950.112807
# Node 101 has objective value 923.928939
# Node 102 has objective value 626.232217
# Node 103 has objective value 647.073431
# Node 104 has objective value 629.605130
# Node 105 has objective value 554.145355
# Node 106 has objective value 0.000000
# Node 107 has objective value 599.862141
# Node 108 has objective value 553.351835
# Node 109 has objective value 839.846914
# Node 110 has objective value 0.000000
# Node 111 has objective value 606.075701
# Node 112 has objective value 0.000000
# Node 113 has objective value 571.252755
# Node 114 has objective value 155.278916
# Node 115 has objective value 189.409616
# Node 116 has objective value 821.184099
# Node 117 has objective value 516.908416
# Node 118 has objective value 474.206487
# Node 119 has objective value 849.157105
# Node 120 has objective value 14.474446
# Node 121 has objective value 0.000000
# Node 122 has objective value 105.205227
# Node 123 has objective value 0.000000
# Node 124 has objective value 170.857717
# Node 125 has objective value 0.000000
# Node 126 has objective value 417.446948
# Node 127 has objective value 780.556708
# Node 128 has objective value 677.371778
# Node 129 has objective value 524.462270
# Node 130 has objective value 4.651938
# Node 131 has objective value 0.000000
# Node 132 has objective value 603.316466
# Node 133 has objective value 705.022620
# Node 134 has objective value 703.106457
# Node 135 has objective value 744.630639
# Node 136 has objective value 367.972321
# Node 137 has objective value 0.000000
# Node 138 has objective value 0.000000
# Node 139 has objective value 105.396600
# Node 140 has objective value 156.812422
# Node 141 has objective value 3.810957
# Node 142 has objective value 914.945073
# Node 143 has objective value 699.702563
# Node 144 has objective value 319.211783
# Node 145 has objective value 662.517423
# Node 146 has objective value 680.195252
# Node 147 has objective value 897.083618
# Node 148 has objective value 0.000000
# Node 149 has objective value 40.000074
# Node 150 has objective value 0.000000
# Node 151 has objective value 0.000000
# Node 152 has objective value 660.765301
# Node 153 has objective value 622.856673
# Node 154 has objective value 428.656916
# Node 155 has objective value 314.758556
# Node 156 has objective value 646.499017
# Node 157 has objective value 0.000000
# Node 158 has objective value 763.032078
# Node 159 has objective value 870.004428
# Node 160 has objective value 454.692094
# Node 161 has objective value 269.240510
# Node 162 has objective value 721.166147
# Node 163 has objective value 0.000000
# Node 164 has objective value 836.508063
# Node 165 has objective value 0.000000
# Node 166 has objective value 633.799645
# Node 167 has objective value 393.706637
# Node 168 has objective value 676.459625
# Node 169 has objective value 620.436982
# Node 170 has objective value 495.974904
# Node 171 has objective value 526.572341
# Node 172 has objective value 761.580521
# Node 173 has objective value 596.062013
# Node 174 has objective value 329.952286
# Node 175 has objective value 0.000000
# Node 176 has objective value 741.741374
# Node 177 has objective value 0.000000
# Node 178 has objective value 15.272339
# Node 179 has objective value 700.412903
# Node 180 has objective value 0.000000
# Node 181 has objective value 188.130309
# Node 182 has objective value 2.331057
# Node 183 has objective value 785.982234
# Node 184 has objective value 182.650870
# Node 185 has objective value 615.379013
# Node 186 has objective value 662.750919
# Node 187 has objective value 303.087872
# Node 188 has objective value 256.357500
# Node 189 has objective value 828.064679
# Node 190 has objective value 0.000000
# Node 191 has objective value 279.255182
# Node 192 has objective value 334.645453
# Node 193 has objective value 121.844232
# Node 194 has objective value 221.539018
# Node 195 has objective value 0.000000
# Node 196 has objective value 349.641513
# Node 197 has objective value 0.000000
# Node 198 has objective value 588.718740
# Node 199 has objective value 130.578902
# Infered objective value :  84833.33670319703

# %%
(total_obj-true_total_obj)/true_total_obj
# Out:
# 0.022691597381337858

# %%
node_rand = random.choice(list(G_true.nodes()))
print("Node : ",node_rand)
x_axis = [x*5 for x in list(range(0,10))]
true_obj_value_node = true_obj_per_node[node_rand]
bla = [x-true_obj_value_node for x in dic_of_obj_per_node_per_iter[node_rand]]
plt.plot(x_axis,bla)
plt.show()
plt.loglog(x_axis,bla)
plt.show()
# Out:
# Node :  188

# %%
bla
# Out:
# [array([434.57384779]),
#  array([300.74601707]),
#  array([298.20151716]),
#  array([297.77115551]),
#  array([297.66259973]),
#  array([18.29032702]),
#  array([-0.66781474]),
#  array([-0.72440712]),
#  array([-0.74105248]),
#  array([-0.74730676])]
